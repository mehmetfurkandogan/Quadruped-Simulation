# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetfurkandogan/Quadruped-Simulation/blob/main/train_gpu_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Replace 'YOUR_GITHUB_TOKEN' and 'YOUR_REPO_URL' with your actual GitHub token and repository URL
github_token = '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'
repo_url = 'https://mehmetfurkandogan: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@github.com/mehmetfurkandogan/Quadruped-Simulation.git'

# Set up Git credentials
os.environ['USER'] = 'mehmetfurkandogan'
os.environ['EMAIL'] = 'mehmetfurkandogan@hotmail.com'
os.environ['PASSWORD'] = github_token

# Clone the repository
# !git clone $repo_url
# Out:
# Cloning into 'Quadruped-Simulation'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 119 (delta 60), reused 82 (delta 30), pack-reused 0
# Receiving objects: 100% (119/119), 5.74 MiB | 18.54 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cd Quadruped-Simulation
# !pwd
# !ls -la
# Out:
# /content/Quadruped-Simulation
# /content/Quadruped-Simulation
# total 64
# drwxr-xr-x 6 root root 4096 Nov 19 14:22 .
# drwxr-xr-x 1 root root 4096 Nov 19 14:22 ..
# drwxr-xr-x 4 root root 4096 Nov 19 14:22 a1_description
# drwxr-xr-x 2 root root 4096 Nov 19 14:22 env
# drwxr-xr-x 8 root root 4096 Nov 19 14:22 .git
# -rw-r--r-- 1 root root   40 Nov 19 14:22 .gitignore
# -rw-r--r-- 1 root root 4261 Nov 19 14:22 load_sb3.py
# -rw-r--r-- 1 root root 3509 Nov 19 14:22 README.md
# -rw-r--r-- 1 root root   99 Nov 19 14:22 requirements.txt
# -rw-r--r-- 1 root root 5047 Nov 19 14:22 run_cpg.py
# -rw-r--r-- 1 root root 6050 Nov 19 14:22 run_sb3.py
# -rw-r--r-- 1 root root 2338 Nov 19 14:22 train_gpu_colab.ipynb
# drwxr-xr-x 2 root root 4096 Nov 19 14:22 utils

# %%
# !pip install gym
# !pip install matplotlib
# !pip install numpy
# !pip install pybullet
# !pip install stable-baselines3[extra]
# !pip install pyqt5
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting pybullet
#   Downloading pybullet-3.2.5.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.5-cp310-cp310-linux_x86_64.whl size=99850143 sha256=a40ea63038a5e678ae2744d40a819abe14050465fe97ae917e3789f82c701110
#   Stored in directory: /root/.cache/pip/wheels/6b/fa/1a/c315a5133f0c9bf202a6daa5d70891120e7fe403e06e3407cc
# Successfully built pybullet
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 4.0 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra])
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.14.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.7.0)
# Collecting shimmy[atari]~=1.3.0 (from stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 45.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable-baselines3[extra]) (6.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=a3dc669caecfd9838e3c6a2b8326db2f6655a493cdc3cd42df948cda5dc2b634
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0 stable-baselines3-2.2.1
# Collecting pyqt5
#   Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 2.5 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.13 (from pyqt5)
#   Downloading PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (338 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 7.2 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2 (from pyqt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, pyqt5
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 pyqt5-5.15.10

# %%
# !pip install pybullet
# Out:
# Collecting pybullet
#   Downloading pybullet-3.2.5.tar.gz (80.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.2.5-cp310-cp310-linux_x86_64.whl size=99850151 sha256=d7be41e38d0c9a1332d407277fea17eb5f76dacc1dc76eff34a30a275078c321
#   Stored in directory: /root/.cache/pip/wheels/6b/fa/1a/c315a5133f0c9bf202a6daa5d70891120e7fe403e06e3407cc
# Successfully built pybullet
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.5

# %%
# %run run_sb3.py
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes
# /content/Quadruped-Simulation/env/quadruped_motor.py:96: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if motor_control_mode is "TORQUE":
# /content/Quadruped-Simulation/env/quadruped_motor.py:109: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if motor_control_mode is "PD":
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 0.0554   |
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 7        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 0.0277   |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 8        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 28       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.7     |
# |    ep_rew_mean     | 0.0185   |
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 8        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 41       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 0.0138   |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 9        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 56       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 0.0216   |
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 10       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 70       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.5     |
# |    ep_rew_mean     | 0.018    |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 11       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 81       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.3     |
# |    ep_rew_mean     | 0.0254   |
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 11       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 93       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.4     |
# |    ep_rew_mean     | 0.0297   |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 11       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 107      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.3     |
# |    ep_rew_mean     | 0.0351   |
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 12       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.4     |
# |    ep_rew_mean     | 0.0365   |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 12       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 134      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.5     |
# |    ep_rew_mean     | 0.0332   |
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 12       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 148      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.6     |
# |    ep_rew_mean     | 0.0304   |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 13       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 163      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.6     |
# |    ep_rew_mean     | 0.0281   |
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 13       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 177      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.6     |
# |    ep_rew_mean     | 0.0261   |
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 13       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 190      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.6     |
# |    ep_rew_mean     | 0.0289   |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 13       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 204      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.7     |
# |    ep_rew_mean     | 0.0312   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 13       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 219      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.8     |
# |    ep_rew_mean     | 0.0327   |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 13       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 234      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.8     |
# |    ep_rew_mean     | 0.0309   |
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 13       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 249      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.9     |
# |    ep_rew_mean     | 0.0293   |
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 13       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 264      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 0.0278   |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 13       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 280      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | 0.0265   |
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 13       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 295      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | 0.0253   |
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 13       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 310      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | 0.0242   |
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 13       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 324      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.1     |
# |    ep_rew_mean     | 0.0232   |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 13       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 339      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0223   |
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 14       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 355      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0225   |
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 14       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 369      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 0.0241   |
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 14       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 385      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0232   |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 14       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 398      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0237   |
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 14       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 412      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0247   |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 14       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 426      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 0.0239   |
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 14       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 442      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0236   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 14       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 453      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.0247   |
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 14       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 468      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.2     |
# |    ep_rew_mean     | 0.024    |
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 14       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 484      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 0.0251   |
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 14       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 499      |
# ---------------------------------
# =================================== Save path is ./logs/intermediate_models/111923144024/
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 0.0244   |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 14       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 515      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.4     |
# |    ep_rew_mean     | 0.0237   |
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 14       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 531      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14.3     |
# |    ep_rew_mean     | 0.0244   |
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 14       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 545      |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/Quadruped-Simulation/run_sb3.py in <module>
#     140
#     141 # Learn and save (may need to train for longer)
# --> 142 model.learn(total_timesteps=1000000, log_interval=1,callback=checkpoint_callback)
#     143 # Don't forget to save the VecNormalize statistics when saving the agent
#     144 model.save( os.path.join(SAVE_PATH, "rl_model" ) )
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/sac/sac.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305         progress_bar: bool = False,
#     306     ) -> SelfSAC:
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     326
#     327         while self.num_timesteps < total_timesteps:
# --> 328             rollout = self.collect_rollouts(
#     329                 self.env,
#     330                 train_freq=self.train_freq,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     558
#     559             # Rescale and perform action
# --> 560             new_obs, rewards, dones, infos = env.step(actions)
#     561
#     562             self.num_timesteps += env.num_envs
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     204         """
#     205         self.step_async(actions)
# --> 206         return self.step_wait()
#     207
#     208     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/vec_normalize.py in step_wait(self)
#     179         where ``dones`` is a boolean vector indicating whether each element is new.
#     180         """
# --> 181         obs, rewards, dones, infos = self.venv.step_wait()
#     182         assert isinstance(obs, (np.ndarray, dict))  # for mypy
#     183         self.old_obs = obs
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      68                 # save final observation where user can get it, then reset
#      69                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 70                 obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71             self._save_obs(env_idx, obs)
#      72         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/monitor.py in reset(self, **kwargs)
#      81                 raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82             self.current_reset_info[key] = value
# ---> 83         return self.env.reset(**kwargs)
#      84
#      85     def step(self, action: ActType) -> Tuple[ObsType, SupportsFloat, bool, bool, Dict[str, Any]]:
#
# /usr/local/lib/python3.10/dist-packages/shimmy/openai_gym_compatibility.py in reset(self, seed, options)
#     233             )
#     234
# --> 235         obs = self.gym_env.reset()
#     236
#     237         if self.render_mode == "human":
#
# /content/Quadruped-Simulation/env/quadruped_gym_env.py in reset(self)
#     606                                                        self._cam_pitch, [0, 0, 0])
#     607
# --> 608     self._settle_robot()
#     609     self._last_action = np.zeros(self._action_dim)
#     610     if self._is_record_video:
#
# /content/Quadruped-Simulation/env/quadruped_gym_env.py in _settle_robot(self)
#     650       if self._is_render:
#     651         time.sleep(0.001)
# --> 652       self._pybullet_client.stepSimulation()
#     653
#     654     # set control mode back
#
# KeyboardInterrupt:
